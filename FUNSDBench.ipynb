# %%
# Benchmark: Text Extraction from FUNSD Dataset
# Comparing ChatGPT and Anthropic Claude models

import numpy as np
import pandas as pd
from datasets import DatasetDict
from sklearn.metrics import jaccard_score
from typing import List, Dict
import anthropic
import base64
from openai import OpenAI
import os
from dotenv import load_dotenv
import re
import azure_di


# Load environment variables from .env file
load_dotenv()

# Replace the API key assignments with these lines
anthropic_api_key = os.getenv("ANTHROPIC_API_KEY")
ANclient = anthropic.Anthropic(api_key=anthropic_api_key)

openai_api_key = os.getenv("OPENAI_API_KEY")
# openai_api_key = "sk-proj-"
OAIclient = OpenAI(api_key=openai_api_key)

# %%
# Load the FUNSD dataset
dataset_path = "dataset/prepared/"
dataset = DatasetDict.load_from_disk(dataset_path)

# %%
system_message = "You are an OCR bot for extraction information various documents. When given an image representing a document, you will extract ALL the content of the document. Under no circumstance leave out any details no matter how small! Extract the text as seen in the document without modifying any characters, even if it's a typo. ALWAYS respond in this form: RESPONSE: <extracted_text>. Do not add any further comments. The extracted text should be in the same order as it appears in the document."

# %%
def encode_image(image_path):
    with open(image_path, "rb") as image_file:
        return base64.b64encode(image_file.read()).decode('utf-8')


def get_model_response(model: str, image_path: str) -> str:
    base64_image = encode_image(image_path)
    if model.startswith("gpt"):
        # OpenAI API call with image
        response = OAIclient.chat.completions.create(
            model=model,
            messages=[
                {
                    "role": "system",
                    "content": [
                        {
                            "type": "text",
                            "text": system_message
                        }
                    ]
                },
                {
                    "role": "user",
                    "content": [
                        {
                            "type": "image_url",
                            "image_url": {"url": f"data:image/png;base64,{base64_image}"}
                        },
                    ],
                }
            ],
            max_tokens=2000
        )
        return response.choices[0].message.content
    elif model.startswith("claude"):
        response = ANclient.messages.create(
            model=model,
            max_tokens=2000,
            system=system_message,
            messages=[
                {
                    "role": "user",
                    "content": [
                        {
                            "type": "image",
                            "source": {
                                "type": "base64",
                                "media_type": "image/png",
                                "data": f"{base64_image}"
                            }
                        }
                    ]
                }
            ]
        )
        return response.content[0].text
    elif model.startswith("azure"):
        response = azure_di.analyze_read(image_path)
        return "RESPONSE: " + response
    else:
        raise ValueError(f"Unknown model: {model}")

# %%
path = dataset["test"][5]["image_path"]

# %%
get_model_response("azure-document-intelligence-prebuilt", path)

# %%
res = get_model_response("gpt-4-turbo", path)
res

# %%
res = get_model_response("claude-3-5-sonnet-20240620", path)
res

# %%
def compare_llm_output_to_labels(llm_output, labels):
    # Step 1: Filter out one-letter strings from labels
    filtered_labels = set([label for label in labels if len(label) > 2])
    
    llm_output_lower = llm_output.lower()

    llm_output_no_spaces = re.sub(r'\s*([^\w\s])\s*', r'\1', llm_output_lower)


    matched_labels = set()
    for label in filtered_labels:
        if (label.lower() in llm_output.lower()) or (label.lower() in llm_output_no_spaces):
            matched_labels.add(label)

    # Calculate metrics
    true_positives = len(matched_labels)
    false_negatives = len(filtered_labels) - len(matched_labels)

    recall = true_positives / (true_positives + false_negatives) if (true_positives + false_negatives) > 0 else 0

    return {
        'llm_output': llm_output,
        'filtered_labels': filtered_labels,
        'matched_labels': matched_labels,
        'unmatched_labels': set(filtered_labels) - matched_labels,
        'recall': recall,
        'true_positives': true_positives,
        'false_negatives': false_negatives
    }

# Example usage
labels = ['AAA', ':', 'BBB', 'CCC', 'DDD', 'EEE ', 'DDD', '132-123/123', 'X@Y.com', '10,000.00', 'A&B Corp.']
llm_output = "AAA is my name BBB CCC EE 132 - 123 / 123 X @ Y . com 10, 000.00 A & B Corp."

result = compare_llm_output_to_labels(llm_output, labels)

print(f"Matched labels: {result['matched_labels']}")
print(f"Unmatched labels: {result['unmatched_labels']}")
print(f"Recall: {result['recall']:.2f}")
print(f"True Positives: {result['true_positives']}")
print(f"False Negatives: {result['false_negatives']}")
# Out:
# Matched labels: {'132-123/123', 'X@Y.com', 'AAA', 'CCC', '10,000.00', 'A&B Corp.', 'BBB'}
# Unmatched labels: {'DDD', 'EEE '}
# Recall: 0.78
# True Positives: 7
# False Negatives: 2

# %%
# List of models to benchmark
models = [
    "azure-document-intelligence-prebuilt",
    "gpt-4-turbo",
    "gpt-4o-mini",
    "claude-3-haiku-20240307",
    "gpt-4o",
    "claude-3-5-sonnet-20240620",
]

# %%
results = {model : [] for model in models}
for i, dat in enumerate(dataset["test"]):
    print(i)
    labels = dat["tokens"]
    image_path = dat["image_path"]
    path = image_path.replace("\\", "/")
    print(f"Image path: {path}")
    try:
        llm_outputs = {model: get_model_response(model, path) for model in models}
    except Exception as e:
        print(f"Error processing image: {path}")
        print(e)
        continue
    for model, llm_output in llm_outputs.items():
        print(f"Model: {model}")
        if "RESPONSE:" not in llm_output:
            print("No response")
            continue
        output = llm_output.split("RESPONSE:")[1]
        result = compare_llm_output_to_labels(llm_output, labels)
        print(result)
        result['file'] = path
        results[model].append(result)

# %%
# results

# %%
for i, dat in enumerate(dataset["train"]):
    print(i)
    labels = dat["tokens"]
    image_path = dat["image_path"]
    path = image_path.replace("\\", "/")
    print(f"Image path: {path}")
    try:
        llm_outputs = {model: get_model_response(model, path) for model in models}
    except Exception as e:
        print(f"Error processing image: {path}")
        print(e)
        continue
    for model, llm_output in llm_outputs.items():
        print(f"Model: {model}")
        if "RESPONSE:" not in llm_output:
            print("No response")
            continue
        output = llm_output.split("RESPONSE:")[1]
        result = compare_llm_output_to_labels(llm_output, labels)
        print(result)
        result['file'] = path
        results[model].append(result)
# Out:
# 0
# Image path: dataset/training_data/images/0000971160.png
# Model: azure-document-intelligence-prebuilt
# {'llm_output': 'RESPONSE: R&D\nR&D QUALITY IMPROVEMENT SUGGESTION/SOLUTION FORM\nName/Phone Ext .: M. Hamann, P. Harper, P. Martinez\nDate:\n9/3/92\nSupervisor/Manager: J. S. Wigand\nR&D Group:\nLicensee\nSuggestion: Discontinue coal retention analyses on licensee submitted product samples. (Note: Coal Retention testing is not performed by most licensees. Other B&W physical measurements as ends stability and inspection for soft spots in cigarettes are thought to be sufficient measures to assure cigarette physical integrity. The proposed action will increase laboratory productivity. )\nSuggested Solution(s): Delete coal retention from the list of standard analyses performed on licensee submitted product samples. Special requests for coal retention testing could still be submitted on an exception basis.\nHave you contacted your Manager/Supervisor?\nYes\nNo\nManager Comments: Manager, please contact suggester and forward comments to the Quality Council.\nqip.wp\n597005708', 'filtered_labels': {'you', 'Comments:', 'the', 'SUGGESTION/', 'SOLUTION', 'not', 'FORM', 'are', 'measurements', 'could', 'Ext.', 'standard', 'IMPROVEMENT', 'proposed', 'retention', 'Discontinue', '(s)', 'qip', 'B&W', 'samples.', 'thought', 'Phone', 'Licensee', 'stability', 'list', 'comments', 'Date:', 'Wigand', 'Manager', 'Solutions', 'Manager,', 'action', 'assure', 'from', 'spots', 'measures', '(Note', 'Hamann', 'Council.', 'submitted', 'basis.', 'will', 'Supervisor?', 'Martinez', 'performed', 'Retention', 'inspection', 'requests', 'Suggestion:', 'testing', 'ends', 'Harper,', 'cigarette', 'analyses', 'productivity', 'Yes', 'and', 'for', 'Suggested', 'contacted', 'coal', 'exception', 'Have', 'product', 'please', 'Special', 'Coal', '597005708', 'still', 'licensees.', 'physical', 'Supervisor', 'samples', 'The', 'increase', 'Manager/', 'licensee', 'Delete', 'Quality', 'Group:', 'laboratory', 'most', 'soft', 'forward', 'suggester', 'sufficient', 'ciparettes', 'R&D', 'Other', 'your', 'contact', 'QUALITY', 'Name', 'integrity.'}, 'matched_labels': {'you', 'Comments:', 'the', 'SUGGESTION/', 'SOLUTION', 'not', 'FORM', 'are', 'measurements', 'could', 'Ext.', 'standard', 'IMPROVEMENT', 'proposed', 'Discontinue', 'retention', '(s)', 'qip', 'B&W', 'samples.', 'thought', 'Phone', 'Licensee', 'stability', 'list', 'comments', 'Date:', 'Wigand', 'Manager', 'Manager,', 'action', 'assure', 'from', 'spots', 'measures', '(Note', 'Hamann', 'Council.', 'submitted', 'basis.', 'will', 'Supervisor?', 'Martinez', 'performed', 'Retention', 'inspection', 'requests', 'Suggestion:', 'testing', 'ends', 'Harper,', 'cigarette', 'analyses', 'productivity', 'Yes', 'and', 'for', 'Suggested', 'contacted', 'coal', 'exception', 'Have', 'product', 'please', 'Special', 'Coal', '597005708', 'still', 'licensees.', 'physical', 'Supervisor', 'samples', 'The', 'increase', 'Manager/', 'licensee', 'Delete', 'Quality', 'Group:', 'laboratory', 'most', 'soft', 'forward', 'suggester', 'sufficient', 'R&D', 'Other', 'your', 'contact', 'QUALITY', 'Name', 'integrity.'}, 'unmatched_labels': {'ciparettes', 'Solutions'}, 'recall': 0.9787234042553191, 'true_positives': 92, 'false_negatives': 2}
# Model: gpt-4-turbo
# {'llm_output': 'RESPONSE: \nR&D QUALITY IMPROVEMENT\nSUGGESTION/SOLUTION FORM\n\nName/Phone Ext.:  M. Haman, P. Harper, P. Martinez Date:  9/3/92\n\nSupervisor/Manager: J. S. Wigand  R&D Group: Licensee\n\nSuggestion: Discontinue coal retention analyses on licensee submitted product samples. (Note: Coal Retention testing is not performed by most licensees. Other B&W physical measurements as ends stability and inspection for soft spots in cigarettes are thought to be sufficient measures to assure cigarette physical integrity. The proposed action will increase laboratory productivity.)\n\nSuggested Solution(s): Delete coal retention from the list of standard analyses performed on licensee submitted product samples. Special requests for coal retention testing could still be submitted on an exception basis.\n\nHave you contacted your Manager/Supervisor?  Yes  No\n\nManager Comments: Manager, please contact suggester and forward comments to the Quality Council.\n\nqip.wp\n', 'filtered_labels': {'you', 'Comments:', 'the', 'SUGGESTION/', 'SOLUTION', 'not', 'FORM', 'are', 'measurements', 'could', 'Ext.', 'standard', 'IMPROVEMENT', 'proposed', 'retention', 'Discontinue', '(s)', 'qip', 'B&W', 'samples.', 'thought', 'Phone', 'Licensee', 'stability', 'list', 'comments', 'Date:', 'Wigand', 'Manager', 'Solutions', 'Manager,', 'action', 'assure', 'from', 'spots', 'measures', '(Note', 'Hamann', 'Council.', 'submitted', 'basis.', 'will', 'Supervisor?', 'Martinez', 'performed', 'Retention', 'inspection', 'requests', 'Suggestion:', 'testing', 'ends', 'Harper,', 'cigarette', 'analyses', 'productivity', 'Yes', 'and', 'for', 'Suggested', 'contacted', 'coal', 'exception', 'Have', 'product', 'please', 'Special', 'Coal', '597005708', 'still', 'licensees.', 'physical', 'Supervisor', 'samples', 'The', 'increase', 'Manager/', 'licensee', 'Delete', 'Quality', 'Group:', 'laboratory', 'most', 'soft', 'forward', 'suggester', 'sufficient', 'ciparettes', 'R&D', 'Other', 'your', 'contact', 'QUALITY', 'Name', 'integrity.'}, 'matched_labels': {'you', 'Comments:', 'the', 'SUGGESTION/', 'SOLUTION', 'not', 'FORM', 'are', 'measurements', 'could', 'Ext.', 'standard', 'IMPROVEMENT', 'proposed', 'Discontinue', 'retention', '(s)', 'qip', 'B&W', 'samples.', 'thought', 'Phone', 'Licensee', 'stability', 'list', 'comments', 'Date:', 'Wigand', 'Manager', 'Manager,', 'action', 'assure', 'from', 'spots', 'measures', '(Note', 'Council.', 'submitted', 'basis.', 'will', 'Supervisor?', 'Martinez', 'performed', 'Retention', 'inspection', 'requests', 'Suggestion:', 'testing', 'ends', 'Harper,', 'cigarette', 'analyses', 'productivity', 'Yes', 'and', 'for', 'Suggested', 'contacted', 'coal', 'exception', 'Have', 'product', 'please', 'Special', 'Coal', 'still', 'licensees.', 'physical', 'Supervisor', 'samples', 'The', 'increase', 'Manager/', 'licensee', 'Delete', 'Quality', 'Group:', 'laboratory', 'most', 'soft', 'forward', 'suggester', 'sufficient', 'R&D', 'Other', 'your', 'contact', 'QUALITY', 'Name', 'integrity.'}, 'unmatched_labels': {'Hamann', 'ciparettes', '597005708', 'Solutions'}, 'recall': 0.9574468085106383, 'true_positives': 90, 'false_negatives': 4}
# Model: gpt-4o-mini
# {'llm_output': 'RESPONSE: \nR&D QUALITY IMPROVEMENT  \nSUGGESTION/SOLUTION FORM  \n\nName/Phone Ext.: M. Hamann, P. Harper, P. Martinez  Date: 9/3/92  \nSupervisor/Manager: J. S. Wigand  R&D Group: Licensee  \n\nSuggestion: Discontinue coal retention analyses on licensee submitted product samples. (Note: Coal Retention testing is not performed by most licensees. Other B&W physical measurements as ends stability and inspection for soft spots in cigarettes are thought to be sufficient measures to assure cigarette physical integrity. The proposed action will increase laboratory productivity.)  \n\nSuggested Solution(s): Delete coal retention from the list of standard analyses performed on licensee submitted product samples. Special requests for coal retention testing could still be submitted on an exception basis.  \n\nHave you contacted your Manager/Supervisor?  Yes  No  \n\nManager Comments: Manager, please contact suggester and forward comments to the Quality Council.  \n\n______________________________________________________________________________  \n\n______________________________________________________________________________  \n\n______________________________________________________________________________  \n\n______________________________________________________________________________  \n\nqfp.wp  \n597005708', 'filtered_labels': {'you', 'Comments:', 'the', 'SUGGESTION/', 'SOLUTION', 'not', 'FORM', 'are', 'measurements', 'could', 'Ext.', 'standard', 'IMPROVEMENT', 'proposed', 'retention', 'Discontinue', '(s)', 'qip', 'B&W', 'samples.', 'thought', 'Phone', 'Licensee', 'stability', 'list', 'comments', 'Date:', 'Wigand', 'Manager', 'Solutions', 'Manager,', 'action', 'assure', 'from', 'spots', 'measures', '(Note', 'Hamann', 'Council.', 'submitted', 'basis.', 'will', 'Supervisor?', 'Martinez', 'performed', 'Retention', 'inspection', 'requests', 'Suggestion:', 'testing', 'ends', 'Harper,', 'cigarette', 'analyses', 'productivity', 'Yes', 'and', 'for', 'Suggested', 'contacted', 'coal', 'exception', 'Have', 'product', 'please', 'Special', 'Coal', '597005708', 'still', 'licensees.', 'physical', 'Supervisor', 'samples', 'The', 'increase', 'Manager/', 'licensee', 'Delete', 'Quality', 'Group:', 'laboratory', 'most', 'soft', 'forward', 'suggester', 'sufficient', 'ciparettes', 'R&D', 'Other', 'your', 'contact', 'QUALITY', 'Name', 'integrity.'}, 'matched_labels': {'you', 'Comments:', 'the', 'SUGGESTION/', 'SOLUTION', 'not', 'FORM', 'are', 'measurements', 'could', 'Ext.', 'standard', 'IMPROVEMENT', 'proposed', 'Discontinue', 'retention', '(s)', 'B&W', 'samples.', 'thought', 'Phone', 'Licensee', 'stability', 'list', 'comments', 'Date:', 'Wigand', 'Manager', 'Manager,', 'action', 'assure', 'from', 'spots', 'measures', '(Note', 'Hamann', 'Council.', 'submitted', 'basis.', 'will', 'Supervisor?', 'Martinez', 'performed', 'Retention', 'inspection', 'requests', 'Suggestion:', 'testing', 'ends', 'Harper,', 'cigarette', 'analyses', 'productivity', 'Yes', 'and', 'for', 'Suggested', 'contacted', 'coal', 'exception', 'Have', 'product', 'please', 'Special', 'Coal', '597005708', 'still', 'licensees.', 'physical', 'Supervisor', 'samples', 'The', 'increase', 'Manager/', 'licensee', 'Delete', 'Quality', 'Group:', 'laboratory', 'most', 'soft', 'forward', 'suggester', 'sufficient', 'R&D', 'Other', 'your', 'contact', 'QUALITY', 'Name', 'integrity.'}, 'unmatched_labels': {'ciparettes', 'qip', 'Solutions'}, 'recall': 0.9680851063829787, 'true_positives': 91, 'false_negatives': 3}
# Model: claude-3-haiku-20240307
# {'llm_output': 'RESPONSE: <extracted_text>\nR&D QUALITY IMPROVEMENT\nSUGGESTION/SOLUTION FORM\n\nName/Phone Ext.: M. Hansen, P. Harper, P. Martinez Date: 9/3/92\n\nSupervisor/Manager: J. S. Wigand RGD Group: License\n\nSuggestion: Discontinue coal retention analyses on licensee submitted\nproduce samples. (Note: Coal Retention testing is not\nrequired by most Licensees. Other RGD physical\nmeasurements as ends stability and inspection for soft\nspots in cigarettes are thought to be sufficient measures\nto assure cigarette physical integrity. The proposed\naction will increase laboratory productivity.)\n\nSuggested Solution(s): Delete coal retention from the list of standard\nanalyses performed on licenses submitted\nproducer samples. Special requests for coal\nretention testing could still be submitted on\nan exception basis.\n\nHave you contacted your Manager/Supervisor? _ Yes _ No\n\nManager Comments: Manager, please contact suggester and forward\ncomments to the Quality Council.\n</extracted_text>', 'filtered_labels': {'you', 'Comments:', 'the', 'SUGGESTION/', 'SOLUTION', 'not', 'FORM', 'are', 'measurements', 'could', 'Ext.', 'standard', 'IMPROVEMENT', 'proposed', 'retention', 'Discontinue', '(s)', 'qip', 'B&W', 'samples.', 'thought', 'Phone', 'Licensee', 'stability', 'list', 'comments', 'Date:', 'Wigand', 'Manager', 'Solutions', 'Manager,', 'action', 'assure', 'from', 'spots', 'measures', '(Note', 'Hamann', 'Council.', 'submitted', 'basis.', 'will', 'Supervisor?', 'Martinez', 'performed', 'Retention', 'inspection', 'requests', 'Suggestion:', 'testing', 'ends', 'Harper,', 'cigarette', 'analyses', 'productivity', 'Yes', 'and', 'for', 'Suggested', 'contacted', 'coal', 'exception', 'Have', 'product', 'please', 'Special', 'Coal', '597005708', 'still', 'licensees.', 'physical', 'Supervisor', 'samples', 'The', 'increase', 'Manager/', 'licensee', 'Delete', 'Quality', 'Group:', 'laboratory', 'most', 'soft', 'forward', 'suggester', 'sufficient', 'ciparettes', 'R&D', 'Other', 'your', 'contact', 'QUALITY', 'Name', 'integrity.'}, 'matched_labels': {'you', 'Comments:', 'the', 'SUGGESTION/', 'SOLUTION', 'not', 'FORM', 'are', 'measurements', 'could', 'Ext.', 'standard', 'IMPROVEMENT', 'proposed', 'Discontinue', 'retention', '(s)', 'samples.', 'thought', 'Phone', 'Licensee', 'stability', 'list', 'comments', 'Date:', 'Wigand', 'Manager', 'Manager,', 'action', 'assure', 'from', 'spots', 'measures', '(Note', 'Council.', 'submitted', 'basis.', 'will', 'Supervisor?', 'Martinez', 'performed', 'Retention', 'inspection', 'requests', 'Suggestion:', 'testing', 'ends', 'Harper,', 'cigarette', 'analyses', 'productivity', 'Yes', 'and', 'for', 'Suggested', 'contacted', 'coal', 'exception', 'Have', 'product', 'please', 'Special', 'Coal', 'still', 'licensees.', 'physical', 'Supervisor', 'samples', 'The', 'increase', 'Manager/', 'licensee', 'Delete', 'Quality', 'Group:', 'laboratory', 'most', 'soft', 'forward', 'suggester', 'sufficient', 'R&D', 'Other', 'your', 'contact', 'QUALITY', 'Name', 'integrity.'}, 'unmatched_labels': {'ciparettes', 'Hamann', 'qip', '597005708', 'B&W', 'Solutions'}, 'recall': 0.9361702127659575, 'true_positives': 88, 'false_negatives': 6}
# Model: gpt-4o
# {'llm_output': 'RESPONSE: \nR&D QUALITY IMPROVEMENT\nSUGGESTION/SOLUTION FORM\n\nName/Phone Ext.: M. Hamann, P. Harper, P. Martinez       Date: 9/3/92\n\nSupervisor/Manager: J. S. Wigand       R&D Group: Licensee\n\nSuggestion: Discontinue coal retention analyses on licensee submitted product samples. (Note: Coal Retention testing is not performed by most licensees. Other B&W physical measurements as ends stability and inspection for soft spots in cigarettes are thought to be sufficient measures to assure cigarette physical integrity. The proposed action will increase laboratory productivity.)\n\nSuggested Solution(s): Delete coal retention from the list of standard analyses performed on licensee submitted product samples. Special requests for coal retention testing could still be submitted on an exception basis.\n\nHave you contacted your Manager/Supervisor? __ Yes __ No\n\nManager Comments: Manager, please contact suggester and forward comments to the Quality Council.\n\nqip.wp \n\n597005708', 'filtered_labels': {'you', 'Comments:', 'the', 'SUGGESTION/', 'SOLUTION', 'not', 'FORM', 'are', 'measurements', 'could', 'Ext.', 'standard', 'IMPROVEMENT', 'proposed', 'retention', 'Discontinue', '(s)', 'qip', 'B&W', 'samples.', 'thought', 'Phone', 'Licensee', 'stability', 'list', 'comments', 'Date:', 'Wigand', 'Manager', 'Solutions', 'Manager,', 'action', 'assure', 'from', 'spots', 'measures', '(Note', 'Hamann', 'Council.', 'submitted', 'basis.', 'will', 'Supervisor?', 'Martinez', 'performed', 'Retention', 'inspection', 'requests', 'Suggestion:', 'testing', 'ends', 'Harper,', 'cigarette', 'analyses', 'productivity', 'Yes', 'and', 'for', 'Suggested', 'contacted', 'coal', 'exception', 'Have', 'product', 'please', 'Special', 'Coal', '597005708', 'still', 'licensees.', 'physical', 'Supervisor', 'samples', 'The', 'increase', 'Manager/', 'licensee', 'Delete', 'Quality', 'Group:', 'laboratory', 'most', 'soft', 'forward', 'suggester', 'sufficient', 'ciparettes', 'R&D', 'Other', 'your', 'contact', 'QUALITY', 'Name', 'integrity.'}, 'matched_labels': {'you', 'Comments:', 'the', 'SUGGESTION/', 'SOLUTION', 'not', 'FORM', 'are', 'measurements', 'could', 'Ext.', 'standard', 'IMPROVEMENT', 'proposed', 'Discontinue', 'retention', '(s)', 'qip', 'B&W', 'samples.', 'thought', 'Phone', 'Licensee', 'stability', 'list', 'comments', 'Date:', 'Wigand', 'Manager', 'Manager,', 'action', 'assure', 'from', 'spots', 'measures', '(Note', 'Hamann', 'Council.', 'submitted', 'basis.', 'will', 'Supervisor?', 'Martinez', 'performed', 'Retention', 'inspection', 'requests', 'Suggestion:', 'testing', 'ends', 'Harper,', 'cigarette', 'analyses', 'productivity', 'Yes', 'and', 'for', 'Suggested', 'contacted', 'coal', 'exception', 'Have', 'product', 'please', 'Special', 'Coal', '597005708', 'still', 'licensees.', 'physical', 'Supervisor', 'samples', 'The', 'increase', 'Manager/', 'licensee', 'Delete', 'Quality', 'Group:', 'laboratory', 'most', 'soft', 'forward', 'suggester', 'sufficient', 'R&D', 'Other', 'your', 'contact', 'QUALITY', 'Name', 'integrity.'}, 'unmatched_labels': {'ciparettes', 'Solutions'}, 'recall': 0.9787234042553191, 'true_positives': 92, 'false_negatives': 2}
# Model: claude-3-5-sonnet-20240620
# {'llm_output': 'RESPONSE: [Logo]\n\nR&D QUALITY IMPROVEMENT\nSUGGESTION/SOLUTION FORM\n\nName/Phone Ext.: M. Hamann, P. Harper, P. Martinez    Date: 9/3/92\n\nSupervisor/Manager: J. S. Wigand                R&D Group: Licensee\n\nSuggestion: Discontinue coal retention analyses on licensee submitted\nproduct samples. (Note: Coal Retention testing is not\nperformed by most licensees. Other R&M physical\nmeasurements as ends stability and inspection for soft\nspots in cigarettes are thought to be sufficient measures\nto assure cigarette physical integrity. The proposed\naction will increase laboratory productivity.)\n\nSuggested Solution(s): Delete coal retention from the list of standard\nanalyses performed on licensee submitted\nproduct samples. Special requests for coal\nretention testing could still be submitted on\nan exception basis.\n\nHave you contacted your Manager/Supervisor?   __ Yes   __ No\n\nManager Comments: Manager, please contact suggester and forward\ncomments to the Quality Council.\n\nqip.wp\n\n597005708', 'filtered_labels': {'you', 'Comments:', 'the', 'SUGGESTION/', 'SOLUTION', 'not', 'FORM', 'are', 'measurements', 'could', 'Ext.', 'standard', 'IMPROVEMENT', 'proposed', 'retention', 'Discontinue', '(s)', 'qip', 'B&W', 'samples.', 'thought', 'Phone', 'Licensee', 'stability', 'list', 'comments', 'Date:', 'Wigand', 'Manager', 'Solutions', 'Manager,', 'action', 'assure', 'from', 'spots', 'measures', '(Note', 'Hamann', 'Council.', 'submitted', 'basis.', 'will', 'Supervisor?', 'Martinez', 'performed', 'Retention', 'inspection', 'requests', 'Suggestion:', 'testing', 'ends', 'Harper,', 'cigarette', 'analyses', 'productivity', 'Yes', 'and', 'for', 'Suggested', 'contacted', 'coal', 'exception', 'Have', 'product', 'please', 'Special', 'Coal', '597005708', 'still', 'licensees.', 'physical', 'Supervisor', 'samples', 'The', 'increase', 'Manager/', 'licensee', 'Delete', 'Quality', 'Group:', 'laboratory', 'most', 'soft', 'forward', 'suggester', 'sufficient', 'ciparettes', 'R&D', 'Other', 'your', 'contact', 'QUALITY', 'Name', 'integrity.'}, 'matched_labels': {'you', 'Comments:', 'the', 'SUGGESTION/', 'SOLUTION', 'not', 'FORM', 'are', 'measurements', 'could', 'Ext.', 'standard', 'IMPROVEMENT', 'proposed', 'Discontinue', 'retention', '(s)', 'qip', 'samples.', 'thought', 'Phone', 'Licensee', 'stability', 'list', 'comments', 'Date:', 'Wigand', 'Manager', 'Manager,', 'action', 'assure', 'from', 'spots', 'measures', '(Note', 'Hamann', 'Council.', 'submitted', 'basis.', 'will', 'Supervisor?', 'Martinez', 'performed', 'Retention', 'inspection', 'requests', 'Suggestion:', 'testing', 'ends', 'Harper,', 'cigarette', 'analyses', 'productivity', 'Yes', 'and', 'for', 'Suggested', 'contacted', 'coal', 'exception', 'Have', 'product', 'please', 'Special', 'Coal', '597005708', 'still', 'licensees.', 'physical', 'Supervisor', 'samples', 'The', 'increase', 'Manager/', 'licensee', 'Delete', 'Quality', 'Group:', 'laboratory', 'most', 'soft', 'forward', 'suggester', 'sufficient', 'R&D', 'Other', 'your', 'contact', 'QUALITY', 'Name', 'integrity.'}, 'unmatched_labels': {'ciparettes', 'B&W', 'Solutions'}, 'recall': 0.9680851063829787, 'true_positives': 91, 'false_negatives': 3}
# 1
# Image path: dataset/training_data/images/0000989556.png
# Model: azure-document-intelligence-prebuilt
# {'llm_output': 'RESPONSE: Page 1 of 10\nRESTRICTED\nBROWN & WILLIAMSON INTERNATIONAL TOBACCO\nPRODUCT SPECIFICATION\nBrand:\nPHOENIX\nStyle:\nHLB - KS\nLicensee Ref. No .:\nCompany:\nB.A.T. CYPRUS\nCountry: CYPRUS\nMarket:\nPlace of Manufacture: NICOSIA\nCIGARETTE MAKING\nPhysical Characteristics\nWeights\noverall Cigarette Length Tobacco Rod Length 64\nFilter Plug Length 20\nFilter Plug Pressure Drop { unencap. ) 56\nFilter Plug Pressure Drop ( encap. )\n56\nCigarette Circumference\n24.75mm\nTotal Pressure Drop (unencap. )\n90\nTotal Pressure Drop {encap. )\n110\nTipping Length 25\nPrint Position (from filter end) 27\nMoisture Content (ex-catcher)\n13.5 %\nFilter Ventilation Rate\nNil %\n84\nmm\nTotal Cigt. Wt.\n974\nmg\nNet Net Tobacco\n749\nmg\nNet Tob. Rod Density 245\nmg/cc\nTipping and Tipping Application\nTipping Paper:\nSupplier(s)\nEcusta\nSupplier Code No(s).\nE. 30639\nAdhesive:\nSupplier(s)\nSwift\nSupplier Code No(s). T.K.9220 Type Printed Imitation Cork\nColor\nImitation Cork\nPerforation Type\nand No. of lines None\nPorosity\nPrint Description\nBrown on yellow\nBobbin Width\n50 mm\nBobbin Length\n2700\nSubstance\n36\ngn/m2\n(Coresta)\nApplication Pattern:\noverall\nx\nSkip\nOther\nmm\nE\nGlue Pree Area:\nN/A\nDimension\nPositioning mm from mouth end\nmm\n( Indicate N/A If Not Applicable)\nPrepared by:\nM. HAMERTON / enm\nDate:\nMay 1, 1985\nDate:\nMay 1, 1985\nApproved by:\nDirector of Technical Operations, Brown & Williamson International Tobacco\nReplaces:\nNew\nDate:\nMay 1, 1985\n0504S\n620419245', 'filtered_labels': {'enm', 'Density', 'Director', 'mouth', 'Place', 'Drop', '(from', 'Characteristics', 'Application', 'Approved', 'Net', 'Style:', 'Width', 'Physical', 'Technical', 'T.K.', 'Rod', 'Circumference', '(ex-catcher)', '974', 'Cork', 'skip', '245', 'NICOSIA', 'Printed', 'Filter', '(coresta)', '749', '620419245', '2700', '(s)', 'gm/', 'Pree', 'ventilation', 'filter', 'Operations,', 'Manufacture:', 'Rate', 'content', 'No(s).', 'Brown', 'Licensee', 'PRODUCT', 'Nil', 'Positioning', 'TOBACCO', 'None', 'Date:', 'Length', '24.75', '(Indicate', 'Pattern:', 'New', 'RESTRICTED', '110', 'Cigt.', 'Glue', '(encap.)', 'Type', '05045', 'Total', 'NO.:', 'Area', 'WILLIAMSON', 'International', 'Brand:', 'from', 'Imitation', 'yellow', 'CIGARETTE', 'by:', 'end', 'Moisture', 'Ecusta', 'HAMERTON', 'Replaces:', 'CYPRUS', 'Macket:', 'Swift', 'Bobbin', 'Company:', 'HLB-', 'and', '1985', 'Paper:', 'Tobacco', 'Weights', 'Wt.', 'mg/cc', 'Description', 'Ref.', 'Print', '13.5', '(unencap.)', 'Supplier(s)', 'No.', 'Williamson', 'Overall', 'BROWN', 'N/A', 'Position', 'Pressure', 'Tipping', 'Applicable)', 'MAKING', 'Supplier', 'Cigarette', 'Prepared', 'Robbin', 'Country:', 'PHOENIX', 'Perforation', 'E.30639', 'Color', 'SPECIFICATION', 'Plug', 'Porosity', 'cork', 'Page', 'Other', 'Tob.', 'encap.', 'end)', 'Not', 'substance', 'Code', 'May', 'Dimension', 'INTERNATIONAL', 'lines', 'Adhesive:', '9220'}, 'matched_labels': {'enm', 'Density', 'Director', 'mouth', 'Place', 'Drop', '(from', 'Characteristics', 'Application', 'Approved', 'Net', 'Style:', 'Width', 'Physical', 'Technical', 'T.K.', 'Rod', 'Circumference', '(ex-catcher)', '974', 'Cork', 'skip', '245', 'NICOSIA', 'Printed', 'Filter', '(coresta)', '2700', '(s)', '749', '620419245', 'Pree', 'ventilation', 'filter', 'Operations,', 'Manufacture:', 'Rate', 'content', 'No(s).', 'Brown', 'Licensee', 'PRODUCT', 'Nil', 'Positioning', 'TOBACCO', 'None', 'Date:', 'Length', '24.75', '(Indicate', 'Pattern:', 'New', 'RESTRICTED', '110', 'Cigt.', 'Glue', '(encap.)', 'Type', 'Total', 'NO.:', 'Area', 'WILLIAMSON', 'International', 'Brand:', 'from', 'Imitation', 'yellow', 'CIGARETTE', 'by:', 'end', 'Moisture', 'Ecusta', 'HAMERTON', 'Replaces:', 'CYPRUS', 'Swift', 'Bobbin', 'Company:', 'HLB-', 'and', '1985', 'Paper:', 'Tobacco', 'Weights', 'Wt.', 'mg/cc', 'Description', 'Ref.', 'Print', '13.5', '(unencap.)', 'Supplier(s)', 'No.', 'Williamson', 'Overall', 'BROWN', 'N/A', 'Position', 'Pressure', 'Tipping', ...
# Model: gpt-4-turbo
# {'llm_output': 'RESPONSE: R E S T R I C T E D\nPage 1 of 10\n\nBROWN & WILLIAMSON INTERNATIONAL TOBACCO\n\nPRODUCT SPECIFICATION\n\nBrand: PHOENIX\nStyle: HUB - KS\nLicensee Ref. No.: ____\nCompany: B.A.T. CYPRUS\nCountry: CYPRUS\nMarket:\nPlace of Manufacture: NICOSIA\n\nCIGARETTE MAKING\n\nPhysical Characteristics Weights\n\nOverall Cigarette Length 84 mm Total Cigt. Wt. 974 mg\nTobacco Rod Length 64 mm\nFilter Plug Length 20 mm Net Net Tobacco 749 mg\nFiltered Plug Pressure Drop (unencap.) 56 mm\nFilter Plug Pressure Drop (encap.) 56 mm Net Tob. Rod Density 245 mg/cc\nCigarette Circumference 24.75 mm\nTotal Pressure Drop (unencap.) 90 mm\nTotal Pressure Drop (encap.) 110 mm\nRipping Length 25 mm\nPrint Position (from filter end) 27 mm\nMoisture content (ex-catcher) 13.5 %\nFilter Ventilation Rate Nil %\n\nTipping and Tipping Application\n\nSupplier(s) Eucusta\nSupplier Code No(s). E.30369\nColor Imitation Cork\nPerforation Type None\nand No. of lines\nPrint description Brown on yellow\nPorosity (Coresta) Overall _ X _Skip __ Other ___\nBobbin Width 50 mm\nBobbin Length 2700m\nSubstance 36 gm/m²\n\nAdhesive: Supplier(s) Swift\nSupplier Code No(s). T.K.9220\nType Printed Imitation Cork\n\nApplication Pattern:\nGlue Free Area: N/A\nDimension mm x mm\nPositioning mm from mouth end\n\n(Indicate N/A If Not Applicable)\n\nPrepared by: M. HAMERTON / enm\nDate: May 1, 1985.\n\nApproved by: Director of Technical Operations,\nBrown & Williamson International Tobacco\n\nDate: May 1, 1985.\n\nReplaces: NEW Date: May 1, 1985\n\n0504S', 'filtered_labels': {'enm', 'Density', 'Director', 'mouth', 'Place', 'Drop', '(from', 'Characteristics', 'Application', 'Approved', 'Net', 'Style:', 'Width', 'Physical', 'Technical', 'T.K.', 'Rod', 'Circumference', '(ex-catcher)', '974', 'Cork', 'skip', '245', 'NICOSIA', 'Printed', 'Filter', '(coresta)', '749', '620419245', '2700', '(s)', 'gm/', 'Pree', 'ventilation', 'filter', 'Operations,', 'Manufacture:', 'Rate', 'content', 'No(s).', 'Brown', 'Licensee', 'PRODUCT', 'Nil', 'Positioning', 'TOBACCO', 'None', 'Date:', 'Length', '24.75', '(Indicate', 'Pattern:', 'New', 'RESTRICTED', '110', 'Cigt.', 'Glue', '(encap.)', 'Type', '05045', 'Total', 'NO.:', 'Area', 'WILLIAMSON', 'International', 'Brand:', 'from', 'Imitation', 'yellow', 'CIGARETTE', 'by:', 'end', 'Moisture', 'Ecusta', 'HAMERTON', 'Replaces:', 'CYPRUS', 'Macket:', 'Swift', 'Bobbin', 'Company:', 'HLB-', 'and', '1985', 'Paper:', 'Tobacco', 'Weights', 'Wt.', 'mg/cc', 'Description', 'Ref.', 'Print', '13.5', '(unencap.)', 'Supplier(s)', 'No.', 'Williamson', 'Overall', 'BROWN', 'N/A', 'Position', 'Pressure', 'Tipping', 'Applicable)', 'MAKING', 'Supplier', 'Cigarette', 'Prepared', 'Robbin', 'Country:', 'PHOENIX', 'Perforation', 'E.30639', 'Color', 'SPECIFICATION', 'Plug', 'Porosity', 'cork', 'Page', 'Other', 'Tob.', 'encap.', 'end)', 'Not', 'substance', 'Code', 'May', 'Dimension', 'INTERNATIONAL', 'lines', 'Adhesive:', '9220'}, 'matched_labels': {'enm', 'Density', 'Director', 'mouth', 'Place', 'Drop', '(from', 'Characteristics', 'Application', 'Approved', 'Net', 'Style:', 'Width', 'Physical', 'Technical', 'T.K.', 'Rod', 'Circumference', '(ex-catcher)', '974', 'Cork', 'skip', '245', 'NICOSIA', 'Printed', 'Filter', '(coresta)', '2700', '(s)', '749', 'gm/', 'ventilation', 'filter', 'Operations,', 'Manufacture:', 'Rate', 'content', 'No(s).', 'Brown', 'Licensee', 'PRODUCT', 'Nil', 'Positioning', 'TOBACCO', 'None', 'Date:', 'Length', '24.75', '(Indicate', 'Pattern:', 'New', '110', 'Cigt.', 'Glue', '(encap.)', 'Type', 'Total', 'NO.:', 'Area', 'WILLIAMSON', 'International', 'Brand:', 'from', 'Imitation', 'yellow', 'CIGARETTE', 'by:', 'end', 'Moisture', 'HAMERTON', 'Replaces:', 'CYPRUS', 'Swift', 'Bobbin', 'Company:', 'and', '1985', 'Tobacco', 'Weights', 'Wt.', 'mg/cc', 'Description', 'Ref.', 'Print', '13.5', '(unencap.)', 'Supplier(s)', 'No.', 'Williamson', 'Overall', 'BROWN', 'N/A', 'Position', 'Pressure', 'Tipping', 'Applicable)', 'MAKING', 'Supplier', 'Cigarette ...
# Model: gpt-4o-mini
# {'llm_output': 'RESPONSE: \nR E S T R I C T E D  \nBROWN & WILLIAMSON INTERNATIONAL TOBACCO  \nPRODUCT SPECIFICATION  \n\nBrand: PHOENIX  \nStyle: HLB - KS  \nLicensee Ref. No.:  \nCompany: B.A.T. CYPRUS  \nCountry: CYPRUS  \nMarket:  \nPlace of Manufacture: NICOSIA  \n\nCIGARETTE MAKING  \n\nPhysical Characteristics                      Weights  \nOverall Cigarette Length                84 mm        Total Cigt. Wt.       974 mg  \nTobacco Rod Length                          64 mm  \nFilter Plug Length                           20 mm        Net Net Tobacco      749 mg  \nFilter Plug Pressure Drop (unencap.)    56 mm  \nFilter Plug Pressure Drop (encap.)      56 mm        Net Tob. Rod Density 245 mg/cc  \nCigarette Circumference                  24.75 mm  \nTotal Pressure Drop (unencap.)         90 mm  \nTotal Pressure Drop (encap.)            110 mm  \nTipping Length                               25 mm  \nPrint Position (from filter end)         27 mm  \nMoisture Content (ex-catcher)            13.5 %  \nFilter Ventilation Rate                      Nil %  \n\nTipping and Tipping Application  \n\nTipping Paper:  \nSupplier(s)                                     Ecusta  \nSupplier Code No(s).                      E.30639  \nColor                                               Imitation Cork  \nPerforation Type and No. of lines    None  \nPorosity                                          - - - (Coresta)  \nPrint Description                            BROWN on yellow  \nBobbin Width                                   50 mm  \nBobbin Length                                 2700 mm  \nSubstance                                       36 gm/m²  \n\n(Indicate N/A If Not Applicable)  \n\nPrepared by:                           M. HAMERTON / enn  \nDate:                                       May 1, 1985  \n\nApproved by:    \n                                            Director of Technical Operations,  \n                                            Brown & Williamson International  \n                                            Tobacco  \nDate:                                       May 1, 1985  \nReplaces:                                 New  \nDate:                                       May 1, 1985  \n\n0504S  \n620419245', 'filtered_labels': {'enm', 'Density', 'Director', 'mouth', 'Place', 'Drop', '(from', 'Characteristics', 'Application', 'Approved', 'Net', 'Style:', 'Width', 'Physical', 'Technical', 'T.K.', 'Rod', 'Circumference', '(ex-catcher)', '974', 'Cork', 'skip', '245', 'NICOSIA', 'Printed', 'Filter', '(coresta)', '749', '620419245', '2700', '(s)', 'gm/', 'Pree', 'ventilation', 'filter', 'Operations,', 'Manufacture:', 'Rate', 'content', 'No(s).', 'Brown', 'Licensee', 'PRODUCT', 'Nil', 'Positioning', 'TOBACCO', 'None', 'Date:', 'Length', '24.75', '(Indicate', 'Pattern:', 'New', 'RESTRICTED', '110', 'Cigt.', 'Glue', '(encap.)', 'Type', '05045', 'Total', 'NO.:', 'Area', 'WILLIAMSON', 'International', 'Brand:', 'from', 'Imitation', 'yellow', 'CIGARETTE', 'by:', 'end', 'Moisture', 'Ecusta', 'HAMERTON', 'Replaces:', 'CYPRUS', 'Macket:', 'Swift', 'Bobbin', 'Company:', 'HLB-', 'and', '1985', 'Paper:', 'Tobacco', 'Weights', 'Wt.', 'mg/cc', 'Description', 'Ref.', 'Print', '13.5', '(unencap.)', 'Supplier(s)', 'No.', 'Williamson', 'Overall', 'BROWN', 'N/A', 'Position', 'Pressure', 'Tipping', 'Applicable)', 'MAKING', 'Supplier', 'Cigarette', 'Prepared', 'Robbin', 'Country:', 'PHOENIX', 'Perforation', 'E.30639', 'Color', 'SPECIFICATION', 'Plug', 'Porosity', 'cork', 'Page', 'Other', 'Tob.', 'encap.', 'end)', 'Not', 'substance', 'Code', 'May', 'Dimension', 'INTERNATIONAL', 'lines', 'Adhesive:', '9220'}, 'matched_labels': {'Density', 'Director', 'Place', 'Drop', '(from', 'Characteristics', 'Application', 'Approved', 'Net', 'Style:', 'Width', 'Physical', 'Technical', 'Rod', 'Circumference', '(ex-catcher)', '974', 'Cork', '245', 'NICOSIA', 'Filter', '(coresta)', '2700', '(s)', '749', '620419245', 'gm/', 'ventilation', 'filter', 'Operations,', 'Manufact ...
# Model: claude-3-haiku-20240307
# {'llm_output': 'RESPONSE: <extracted_text>\nRESTRICTED\nBROWN & WILLIAMSON INTERNATIONAL TOBACCO\nPRODUCT SPECIFICATION\nBrand: PHOENIX\nCompany: B.A.T. CYPRUS\nStyle: HEB-KS\nCountry: CYPRUS\nLicense Ref. No.: _______________ Market: _____________\nPlace of Manufacturer: NICOSIA\nCIGARETTE MAKING\nPhysical Characteristics\nWeights\nOverall Cigarette Length\n84 mm Total Cigt. Wt.\n974 mg\nTobacco Rod Length\n64 mm Net Net Tobacco\n749 mg\nFilter Plug Length\n20 mm Net Tob. Rod Density 245 mg/cc\nFilter Plug Pressure Drop (unencap.)\n55 mm\nFilter Plug Pressure Drop (encap.)\n56 mm\nCigarette Circumference\n24.75mm\nTotal Pressure Drop (unencap.)\n90 mm\nTotal Pressure Drop (encap.)\n110 mm\nTipping Length\n25 mm\nPrint Position (from filter end)\n27 mm\nMoisture Content (ex-catcher)\n13.5 %\nFilter Ventilation Rate\nNil %\nTipping and Tipping Application\nTipping Paper:\nEcusta\nAdhesive:\nSupplier(s)________ Swift _________\nSupplier Code No(s). E.30639\nSupplier Code No(s). T.K.9220\nColor\nFiltration Cork\nType Printed Imitation Cork\nPerforation Type\nand No. of Lines\nNone\nApplication Pattern:\nOverall X Skip _____ Other _____\nPorosity\n(Coresta)\nGlue Free Area: N/A\nPrint Description BROWN on yellow\nDimension\nmm x mm\nBobbin Width\n50 mm\nBobbin Length\n2700 mm Positioning\nmm from mouth end\nSubstance\n36\ngm/m²\n(Indicate N/A If Not Applicable)\nPrepared by: M. HAMPTONF enm\nDate: May 1, 1985\nApproved by: __________________________________________\nDirector of Technical Operations,\nBrown & Williamson International\nDate: May 1, 1985\nTobacco\nReplaces: NEW\nDate: May 1, 1985\n05945</extracted_text>', 'filtered_labels': {'enm', 'Density', 'Director', 'mouth', 'Place', 'Drop', '(from', 'Characteristics', 'Application', 'Approved', 'Net', 'Style:', 'Width', 'Physical', 'Technical', 'T.K.', 'Rod', 'Circumference', '(ex-catcher)', '974', 'Cork', 'skip', '245', 'NICOSIA', 'Printed', 'Filter', '(coresta)', '749', '620419245', '2700', '(s)', 'gm/', 'Pree', 'ventilation', 'filter', 'Operations,', 'Manufacture:', 'Rate', 'content', 'No(s).', 'Brown', 'Licensee', 'PRODUCT', 'Nil', 'Positioning', 'TOBACCO', 'None', 'Date:', 'Length', '24.75', '(Indicate', 'Pattern:', 'New', 'RESTRICTED', '110', 'Cigt.', 'Glue', '(encap.)', 'Type', '05045', 'Total', 'NO.:', 'Area', 'WILLIAMSON', 'International', 'Brand:', 'from', 'Imitation', 'yellow', 'CIGARETTE', 'by:', 'end', 'Moisture', 'Ecusta', 'HAMERTON', 'Replaces:', 'CYPRUS', 'Macket:', 'Swift', 'Bobbin', 'Company:', 'HLB-', 'and', '1985', 'Paper:', 'Tobacco', 'Weights', 'Wt.', 'mg/cc', 'Description', 'Ref.', 'Print', '13.5', '(unencap.)', 'Supplier(s)', 'No.', 'Williamson', 'Overall', 'BROWN', 'N/A', 'Position', 'Pressure', 'Tipping', 'Applicable)', 'MAKING', 'Supplier', 'Cigarette', 'Prepared', 'Robbin', 'Country:', 'PHOENIX', 'Perforation', 'E.30639', 'Color', 'SPECIFICATION', 'Plug', 'Porosity', 'cork', 'Page', 'Other', 'Tob.', 'encap.', 'end)', 'Not', 'substance', 'Code', 'May', 'Dimension', 'INTERNATIONAL', 'lines', 'Adhesive:', '9220'}, 'matched_labels': {'enm', 'Density', 'Director', 'mouth', 'Place', 'Drop', '(from', 'Characteristics', 'Application', 'Approved', 'Net', 'Style:', 'Width', 'Physical', 'Technical', 'T.K.', 'Rod', 'Circumference', '(ex-catcher)', '974', 'Cork', 'skip', '245', 'NICOSIA', 'Printed', 'Filter', '(coresta)', '2700', '(s)', '749', 'gm/', 'ventilation', 'filter', 'Operations,', 'Rate', 'content', 'No(s).', 'Brown', 'PRODUCT', 'Nil', 'Positioning', 'TOBACCO', 'None', 'Date:', 'Length', '24.75', '(Indicate', 'Pattern:', 'New', 'RESTRICTED', '110', 'Cigt.', 'Glue', '(encap.)', 'Type', 'Total', 'NO.:', 'Area', 'WILLIAMSON', 'International', 'Brand:', 'from', 'Imitation', 'yellow', 'CIGARETTE', 'by:', 'end', 'Moisture', 'Ecusta', 'Replaces:', 'CYPRUS', 'Swift', 'Bobbin', 'Company:', 'and', '1985', 'Paper:', 'Tobacco', 'Weights', 'Wt.', 'mg/cc', 'Description', 'Ref.', 'Print', '13.5', '(unencap.)', 'Supplier(s)', 'No.', 'Williamson', 'Overall', 'BROWN', 'N/ ...
# Model: gpt-4o
# {'llm_output': 'RESPONSE: R E S T R I C T E D\nPage 1 of 10\n\nBROWN & WILLIAMSON INTERNATIONAL TOBACCO\n\nPRODUCT SPECIFICATION\n\nBrand:               PHOENIX                         Company:  B.A.T. CYPRUS\nStyle:               HLB - KS                         Country:  CYPRUS\nLicensee Ref. No.:   ______                         Market:\nPlace of Manufacture: NICOSIA\n\nCIGARETTE MAKING\n\nPhysical Characteristics\nOverall Cigarette Length       84 mm     Total Cigt. Wt.       974 mg\nTobacco Rod Length             64 mm     Net Net Tobacco       749 mg\nFilter Plug Length             20 mm     Net Tob. Rod Density  245 mg/cc\nFilter Plug Pressure Drop (unencap.,)  56 mm\nFilter Plug Pressure Drop (encap.,)    56 mm\nCigarette Circumference         24.75mm\nTotal Pressure Drop (unencap.)  90 mm\nTotal Pressure Drop (encap.)  110 mm\nTipping Length                 25 mm\nPrint Position (from filter end) 27 mm\nMoisture Content (ex-catcher)  13.5 %\nFilter Ventilation Rate         Nil %\n\nTipping and Tipping Application\nTipping Paper:                     Adhesive: \nSupplier(s)                          Ecusta      Supplier(s)                      Swift\nSupplier Code No(s).     E. 30639     Supplier Code No(s).    T.K. 9220\nColor                          Imitation Cork     Type                  Printed Imitation Cork\nPerforation Type\nand No. of lines                     None       Application Pattern:\nPorosity                           _                   (Coresta)  Overall      x     Skip       Other\nPrint Description      BROWN on yellow       Glue Free Area:     N/A\nBobbin Width                          50 mm      Glue Free Area:       N/A\nBobbin Length                       2700 m      Dimension              mm x    mm\nSubstance                          36 gm/m2     Positioning          mm from mouth end\n\n(Indicate N/A If Not Applicable) \n\nPrepared by:         M. HAMERTON / enn\n\nDate:         May 1, 1985\n\nApproved by:  ______________\nDirector of Technical Operations,\nBrown & Williamson International Tobacco \n\nDate:         May 1, 1985\n\nReplaces:          New                   Date:         May 1, 1985\n\n0504S\n620419245', 'filtered_labels': {'enm', 'Density', 'Director', 'mouth', 'Place', 'Drop', '(from', 'Characteristics', 'Application', 'Approved', 'Net', 'Style:', 'Width', 'Physical', 'Technical', 'T.K.', 'Rod', 'Circumference', '(ex-catcher)', '974', 'Cork', 'skip', '245', 'NICOSIA', 'Printed', 'Filter', '(coresta)', '749', '620419245', '2700', '(s)', 'gm/', 'Pree', 'ventilation', 'filter', 'Operations,', 'Manufacture:', 'Rate', 'content', 'No(s).', 'Brown', 'Licensee', 'PRODUCT', 'Nil', 'Positioning', 'TOBACCO', 'None', 'Date:', 'Length', '24.75', '(Indicate', 'Pattern:', 'New', 'RESTRICTED', '110', 'Cigt.', 'Glue', '(encap.)', 'Type', '05045', 'Total', 'NO.:', 'Area', 'WILLIAMSON', 'International', 'Brand:', 'from', 'Imitation', 'yellow', 'CIGARETTE', 'by:', 'end', 'Moisture', 'Ecusta', 'HAMERTON', 'Replaces:', 'CYPRUS', 'Macket:', 'Swift', 'Bobbin', 'Company:', 'HLB-', 'and', '1985', 'Paper:', 'Tobacco', 'Weights', 'Wt.', 'mg/cc', 'Description', 'Ref.', 'Print', '13.5', '(unencap.)', 'Supplier(s)', 'No.', 'Williamson', 'Overall', 'BROWN', 'N/A', 'Position', 'Pressure', 'Tipping', 'Applicable)', 'MAKING', 'Supplier', 'Cigarette', 'Prepared', 'Robbin', 'Country:', 'PHOENIX', 'Perforation', 'E.30639', 'Color', 'SPECIFICATION', 'Plug', 'Porosity', 'cork', 'Page', 'Other', 'Tob.', 'encap.', 'end)', 'Not', 'substance', 'Code', 'May', 'Dimension', 'INTERNATIONAL', 'lines', 'Adhesive:', '9220'}, 'matched_labels': {'Density', 'Director', 'mouth', 'Place', 'Drop', '(from', 'Characteristics', 'Application', 'Approved', 'Net', 'Style:', 'Width', 'Physical', 'Technical', 'T.K.', 'Rod', 'Circumference', '(ex-catcher)', '974', 'Cork', 'skip', '245', 'NICOSIA', 'Printed', 'Filter', '(coresta)', '2700', '(s)', '749', '620419245', 'gm/', 'ventilation', 'filter', 'Operations,', 'Manufacture:', 'Rate', 'conten ...
# Model: claude-3-5-sonnet-20240620
# {'llm_output': 'RESPONSE: RESTRICTED\nPage 1 of 10\n\nBROWN & WILLIAMSON INTERNATIONAL TOBACCO\n\nPRODUCT SPECIFICATION\n\nBrand:    PHOENIX                       Company:  B.A.T. CYPRUS\nStyle:    HLH - KS                      Country:  CYPRUS\nLicensee Ref. No.:                      Market:\n                                        Place of Manufacture:  NICOSIA\n\nCIGARETTE MAKING\n\nPhysical Characteristics                           Weights\n\nOverall Cigarette Length            84  mm  Total Cigt. Wt.      974     mg\nTobacco Rod Length                  64  mm\nFilter Plug Length                  20  mm  Net Net Tobacco      749     mg\nFilter Plug Pressure Drop (unencap.) 56  mm\nFilter Plug Pressure Drop (encap.)   56  mm  Net Tob. Rod Density 245  mg/cc\nCigarette Circumference             24.75mm\nTotal Pressure Drop (unencap.)       90  mm\nTotal Pressure Drop (encap.)        110  mm\nTipping Length                       25  mm\nPrint Position (from filter end)     27  mm\nMoisture Content (ex-catcher)       13.5 %\nFilter Ventilation Rate             NIL %\n\nTipping and Tipping Application\n\nTipping Paper:                           Adhesive:\nSupplier(s)        Ecusta                Supplier(s)   Swift\nSupplier Code No(s). F.30639             Supplier Code No(s). T.R.9220\nColor              Imitation Cork        Type  Printed Imitation Cork\nPerforation Type\nand No. of Lines   None                  Application Pattern:\nPorosity                     (coresta)   Overall   X   Skip      Other\nPrint Description  Brown on yellow\nBobbin Width           50        mm      Glue Free Area: N/A\nBobbin Length         2700       mm      Dimension         mm x        mm\nSubstance              36     gm/m²      Positioning       mm from mouth end\n\n(Indicate N/A If Not Applicable)\n                                   Prepared by:    M. HAMERSTON / krm\n\n                                   Date:           May 1, 1985\n\n                                   Approved by:\n                                                   Director of Technical Operations,\n                                                   Brown & Williamson International\nDate:    May 1, 1985                               Tobacco\n\nReplaces:    New                  Date:            May 1, 1985\n\n05948\n                                                                    620419345', 'filtered_labels': {'enm', 'Density', 'Director', 'mouth', 'Place', 'Drop', '(from', 'Characteristics', 'Application', 'Approved', 'Net', 'Style:', 'Width', 'Physical', 'Technical', 'T.K.', 'Rod', 'Circumference', '(ex-catcher)', '974', 'Cork', 'skip', '245', 'NICOSIA', 'Printed', 'Filter', '(coresta)', '749', '620419245', '2700', '(s)', 'gm/', 'Pree', 'ventilation', 'filter', 'Operations,', 'Manufacture:', 'Rate', 'content', 'No(s).', 'Brown', 'Licensee', 'PRODUCT', 'Nil', 'Positioning', 'TOBACCO', 'None', 'Date:', 'Length', '24.75', '(Indicate', 'Pattern:', 'New', 'RESTRICTED', '110', 'Cigt.', 'Glue', '(encap.)', 'Type', '05045', 'Total', 'NO.:', 'Area', 'WILLIAMSON', 'International', 'Brand:', 'from', 'Imitation', 'yellow', 'CIGARETTE', 'by:', 'end', 'Moisture', 'Ecusta', 'HAMERTON', 'Replaces:', 'CYPRUS', 'Macket:', 'Swift', 'Bobbin', 'Company:', 'HLB-', 'and', '1985', 'Paper:', 'Tobacco', 'Weights', 'Wt.', 'mg/cc', 'Description', 'Ref.', 'Print', '13.5', '(unencap.)', 'Supplier(s)', 'No.', 'Williamson', 'Overall', 'BROWN', 'N/A', 'Position', 'Pressure', 'Tipping', 'Applicable)', 'MAKING', 'Supplier', 'Cigarette', 'Prepared', 'Robbin', 'Country:', 'PHOENIX', 'Perforation', 'E.30639', 'Color', 'SPECIFICATION', 'Plug', 'Porosity', 'cork', 'Page', 'Other', 'Tob.', 'encap.', 'end)', 'Not', 'substance', 'Code', 'May', 'Dimension', 'INTERNATIONAL', 'lines', 'Adhesive:', '9220'}, 'matched_labels': {'Density', 'Director', 'mouth', 'Place', 'Drop', '(from', 'Characteristics', 'Application', 'Approved', 'Net', 'Style:', 'Width', 'Physical', 'Technical', 'Rod', 'Circumference', '(ex-catch ...
# 2
# Image path: dataset/training_data/images/0000990274.png
# Model: azure-document-intelligence-prebuilt
# {'llm_output': 'RESPONSE: REQUEST NO. :\n25-84\nDATE:\nMarch 27, 1984\nINITIATED BY:\nP. H. HARPER\nPHA\nCOMPLETION\nTARGET DATE:\nApril 13, 1984\nCOUNTRY:\nBELGIUM\nPRODUCT:\nLUCKY STRIKE Filter and VICEROY\nNATURE OF WORK:\nIL PHHV\nSERVICE REQUEST FROM R&D BY INTERNATIONAL LICENSEE OPERATIONS\nRECEIVED APR 2 1984 P.H.H.\nAdvise if locally obtained Yucatan Honey (sample enclosed) is an acceptable substitute for HALWAY.\nR&D COMMENTS:\nBY:\nDATE:\nNOTES:\nMH/enm\n0036/(r) #2894M\nTarget dide OK\nPTA 281284\na) Nature of work should be specified in exact terms.\nb) R&D should advise if completion date cannot be met.\nc) Two copies of this form to be sent to R&D by initiator and R&D is to return to T.O. one completed copy.\n620429480', 'filtered_labels': {'25-', 'one', 'DATE:', 'Two', 'copy.', 'substitute', '29Mar', 'HARPER', 'enm', 'STRIKE', 'Honey', 'TARGET', 'COMPLETION', 'Target', '1984', '27,', 'date', 'sent', '0036/', 'the', 'April', '(sample', 'LICENSEE', 'COMMENTS:', 'SERVICE', 'copies', 'obtained', 'should', 'MH/', '2894M', 'NOTES:', 'initiator', '620429480', 'and', 'NATURE', 'for', 'terms.', 'RECEIVED', 'advise', 'work', 'form', 'VICEROY', 'Yucatan', 'return', 'BELGIUM', 'WORK:', 'Advise', 'APR', 'exact', 'Nature', '13,', 'COUNTRY:', 'met.', 'acceptable', 'completed', 'BY:', 'cannot', 'HALWAY.', 'FROM', 'locally', 'specified', 'NO.:', 'this', 'March', 'LUCKY', 'INITIATED', 'REQUEST', 'Filter', 'INTERNATIONAL', 'enclosed)', 'completion', '(r)', 'PRODUCT:', 'OPERATIONS', 'PHH'}, 'matched_labels': {'25-', 'one', 'DATE:', 'copy.', 'substitute', 'OPERATIONS', 'HARPER', 'enm', 'STRIKE', 'Honey', 'TARGET', 'COMPLETION', 'Target', '1984', 'sent', 'date', '27,', '0036/', 'April', '(sample', 'LICENSEE', 'COMMENTS:', 'SERVICE', 'obtained', 'should', 'MH/', '2894M', 'PRODUCT:', 'NOTES:', 'initiator', '620429480', 'and', 'NATURE', 'for', 'terms.', 'RECEIVED', 'advise', 'form', 'VICEROY', 'Yucatan', 'return', 'BELGIUM', 'WORK:', 'Advise', 'APR', 'exact', 'Nature', '13,', 'COUNTRY:', 'met.', 'acceptable', 'completed', 'BY:', 'cannot', 'HALWAY.', 'FROM', 'locally', 'specified', 'NO.:', 'this', 'March', 'LUCKY', 'INITIATED', 'REQUEST', 'Filter', 'INTERNATIONAL', 'enclosed)', 'Two', 'completion', 'copies', '(r)', 'work', 'PHH'}, 'unmatched_labels': {'29Mar', 'the'}, 'recall': 0.9733333333333334, 'true_positives': 73, 'false_negatives': 2}
# Model: gpt-4-turbo
# ...
# 148
# Image path: dataset/training_data/images/93455715.png
# Model: azure-document-intelligence-prebuilt
# {'llm_output': 'RESPONSE: COMPETITIVE ACTIVITIES AND PROMOTIONS\nREPORTED BY:\nR. E. Klein, Regional Sales Manager, Cleveland, OH\nDATE: 4/7/88\nSOURCE OF INFORMATION:\nBest Cigarette Co., Mentor, OH\nMANUFACTURERS :\nR. J. REYNOLDS AND PHILIP MORRIS\nTYPE OF PROMOTION:\nSEE ATTACHED CORRESPONDENCE REGARDING:\n. R. J. REYNOLDS SPRING DIRECT ACCOUNT INCENTIVE PROGRAM\n. Philip Morris - SPECIAL PROMOTIONS ON MARLBORO AND\nCAMBRIDGE CIGARETTES\nHOW WIDESPREAD?\nOTHER COMMENTS:\nCc: Mr. J. R. Ave Mr. R. H. Orcutt Mr. M. A. Peterson Mr. T. H. Mau Ms. S. Ridgway Mr. J. P. Mastandrea Mr. P. A. Lawless\nMr. L. Gordon Mr. J. E. Daghlian Mr. R. S. Goldbrenner Ms. E. R. Harrow Ms. S. F. Smith\nMr. G. R. Telford Dr. S. T. Jones Mr. C. Toti Mr. N. P. Ruffalo\nMr. T. L. Achey Mr. P. J. McCann Mr. A. J. Giacoio Mr. L. H. Kersh Mr. R. G. Ryan\n93455715', 'filtered_labels': {'DATE:', 'SEE', 'HOW', 'Telford', 'Ridgway', 'CAMBRIDGE', 'REYNOLDS', 'Giacoio', 'Dr.', 'Mau', 'Regional', 'DIRECT', 'REGARDING:', 'Philip', 'Morris-', 'Cigarette', 'McCann', 'Daghlian', 'CORRESPONDENCE', 'Achey', 'Peterson', 'PHILIP', 'Mentor,', '4/7/88', 'PROGRAM', 'Klein,', 'TYPE', 'Lawless', 'INCENTIVE', 'Toti', 'Mastandrea', 'COMMENTS:', 'Goldbrenner', 'MAKLBORO', 'Ave', 'PROMOTIONS', 'CIGARETTES', 'Sales', 'Orcutt', 'OTHER', 'ATTACHED', 'COMPETITIVE', 'WIDESPREAD?', 'INFORMATION:', 'PROMOTION:', 'Smith', 'SOURCE', 'MORRIS', 'Mr.', 'ACCOUNT', 'MANUFACTURERS:', 'Ruffalo', 'Co.,', 'Harrow', 'Manager,', '93455715', 'Jones', 'BY:', 'cc:', 'Gordon', 'Kersh', 'AND', 'REPORTED', 'Cleveland,', 'SPECIAL', 'SPRING', 'ACTIVITIES', 'Ryan', 'Best', 'Ms.'}, 'matched_labels': {'DATE:', 'SEE', 'Telford', 'HOW', 'Ridgway', 'CAMBRIDGE', 'REYNOLDS', 'Giacoio', 'Dr.', 'Mau', 'DIRECT', 'Regional', 'REGARDING:', 'McCann', 'Philip', 'Morris-', 'Cigarette', 'Daghlian', 'CORRESPONDENCE', 'Achey', 'Peterson', 'PHILIP', 'Mentor,', '4/7/88', 'PROGRAM', 'Klein,', 'TYPE', 'Lawless', 'INCENTIVE', 'Toti', 'Mastandrea', 'COMMENTS:', 'Goldbrenner', 'Ave', 'PROMOTIONS', 'CIGARETTES', 'Sales', 'Orcutt', 'OTHER', 'ATTACHED', 'COMPETITIVE', 'WIDESPREAD?', 'INFORMATION:', 'PROMOTION:', 'Smith', 'SOURCE', 'MORRIS', 'Mr.', 'ACCOUNT', 'MANUFACTURERS:', 'Ruffalo', 'Co.,', 'Harrow', 'Manager,', '93455715', 'Jones', 'BY:', 'cc:', 'Gordon', 'Kersh', 'AND', 'REPORTED', 'Cleveland,', 'SPECIAL', 'SPRING', 'ACTIVITIES', 'Ryan', 'Best', 'Ms.'}, 'unmatched_labels': {'MAKLBORO'}, 'recall': 0.9857142857142858, 'true_positives': 69, 'false_negatives': 1}
# Model: gpt-4-turbo
# {'llm_output': 'RESPONSE: \n\nCOMPETITIVE ACTIVITIES AND PROMOTIONS\n\nREPORTED BY: R. E. Klein, Regional Sales Manager, Cleveland, OH\n\nDATE: 4/7/88\n\nSOURCE OF INFORMATION: Best Cigarette Co., Mentor, OH\n\nMANUFACTURERS: R. J. REYNOLDS AND PHILIP MORRIS\n\nTYPE OF PROMOTION: SEE ATTACHED CORRESPONDENCE REGARDING:\n● R. J. REYNOLDS SPRING DIRECT ACCOUNT INCENTIVE PROGRAM\n● Philip Morris - SPECIAL PROMOTIONS ON MARLBORO AND CAMBRIDGE CIGARETTES\n\nHOW WIDESPREAD?\n\nOTHER COMMENTS:\n\ncc: Mr. J. R. Ave\n    Mr. R. H. Orcutt\n    Mr. M. A. Peterson\n    Mr. T. H. Ma\n    Ms. S. Ridgway\n    Mr. J. P. Mastandrea\n    Mr. L. Gordon\n    Mr. G. R. Telford\n    Dr. S. T. Jones\n    Mr. C. Toti\n    Mr. N. P. Ruffalo\n    Mr. T. L. Achey\n    Mr. P. J. McCann\n    Mr. A. J. Giacoio\n    Mr. R. H. Kersh\n    Mr. L. G. Ryan\n    Mr. P. A. Lawless\n    Mr. J. E. Daghlian\n    Mr. R. S. Goldbrenner\n    Ms. E. R. Harrow\n    Ms. S. F. Smith', 'filtered_labels': {'DATE:', 'SEE', 'HOW', 'Telford', 'Ridgway', 'CAMBRIDGE', 'REYNOLDS', 'Giacoio', 'Dr.', 'Mau', 'Regional', 'DIRECT', 'REGARDING:', 'Philip', 'Morris-', 'Cigarette', 'McCann', 'Daghlian', 'CORRESPONDENCE', 'Achey', 'Peterson', 'PHILIP', 'Mentor,', '4/7/88', 'PROGRAM', 'Klein,', 'TYPE', 'Lawless', 'INCENTIVE', 'Toti', 'Mastandrea', 'COMMENTS:', 'Goldbrenner', 'MAKLBORO', 'Ave', 'PROMOTIONS', 'CIGARETTES', 'Sales', 'Orcutt', 'OTHER', 'ATTACHED', 'COMPETITIVE', 'WIDESPREAD?', 'INFORMATION:', 'PROMOTION:', 'Smith', 'SOURCE', 'MORRIS', 'Mr.', 'ACCOUNT', 'MANUFACTURERS:', 'Ruffalo', 'Co.,', 'Harrow', 'Manager,', '93455715', 'Jones', 'BY:', 'cc:', 'Gordon', 'Kersh', 'AND', 'REPORTED', 'Cleveland,', 'SPECIAL', 'SPRING', 'ACTIVITIES', 'Ryan', 'Best', 'Ms.'}, 'matched_labels': {'DATE:', 'SEE', 'Telford', 'HOW', 'Ridgway', 'CAMBRIDGE', 'REYNOLDS', 'Giacoio', 'Dr.', 'DIRECT', 'Regional', 'REGARDING:', 'McCann', 'Philip', 'Morris-', 'Cigarette', 'Daghlian', 'CORRESPONDENCE', 'Achey', 'Peterson', 'PHILIP', 'Mentor,', '4/7/88', 'PROGRAM', 'Klein,', 'TYPE', 'Lawless', 'INCENTIVE', 'Toti', 'Mastandrea', 'COMMENTS:', 'Goldbrenner', 'Ave', 'PROMOTIONS', 'CIGARETTES', 'Sales', 'Orcutt', 'OTHER', 'ATTACHED', 'COMPETITIVE', 'WIDESPREAD?', 'INFORMATION:', 'PROMOTION:', 'Smith', 'SOURCE', 'MORRIS', 'Mr.', 'ACCOUNT', 'MANUFACTURERS:', 'Ruffalo', 'Co.,', 'Harrow', 'Manager,', 'Jones', 'BY:', 'cc:', 'Gordon', 'Kersh', 'AND', 'REPORTED', 'Cleveland,', 'SPECIAL', 'SPRING', 'ACTIVITIES', 'Ryan', 'Best', 'Ms.'}, 'unmatched_labels': {'Mau', '93455715', 'MAKLBORO'}, 'recall': 0.9571428571428572, 'true_positives': 67, 'false_negatives': 3}
# Model: gpt-4o-mini
# {'llm_output': 'RESPONSE: \nCOMPETITIVE ACTIVITIES AND PROMOTIONS\n\nREPORTED BY: R. E. Klein, Regional Sales Manager, Cleveland, OH\n\nDATE: 4/7/88\n\nSOURCE OF INFORMATION: Best Cigarette Co., Mentor, OH\n\nMANUFACTURERS: R. J. REYNOLDS AND PHILIP MORRIS\n\nTYPE OF PROMOTION: SEE ATTACHED CORRESPONDENCE REGARDING:\n• R. J. REYNOLDS SPRING DIRECT ACCOUNT INCENTIVE PROGRAM\n• Philip Morris - SPECIAL PROMOTIONS ON MARLBORO AND CAMBRIDGE CIGARETTES\n\nHOW WIDESPRAD?\n\nOTHER COMMENTS:\n\ncc: Mr. J. R. Ave\nMr. R. H. Orcutt\nMr. M. A. Peterson\nMr. T. H. Mau\nMs. S. Ridgway\nMr. J. P. Mastandrea\nMr. L. Gordon\nMr. G. R. Telford\nDr. S. T. Jones\nMr. C. Toti\nMr. N. P. Ruffalo\nMr. T. L. Achey\nMr. P. J. McCann\nMr. A. J. Giacoio\nMr. L. H. Kersh\nMr. R. G. Ryan\nMr. P. A. Lawless\nMr. J. E. Daghlian\nMr. R. S. Goldbrenner\nMs. E. R. Harrow\nMs. S. F. Smith', 'filtered_labels': {'DATE:', 'SEE', 'HOW', 'Telford', 'Ridgway', 'CAMBRIDGE', 'REYNOLDS', 'Giacoio', 'Dr.', 'Mau', 'Regional', 'DIRECT', 'REGARDING:', 'Philip', 'Morris-', 'Cigarette', 'McCann', 'Daghlian', 'CORRESPONDENCE', 'Achey', 'Peterson', 'PHILIP', 'Mentor,', '4/7/88', 'PROGRAM', 'Klein,', 'TYPE', 'Lawless', 'INCENTIVE', 'Toti', 'Mastandrea', 'COMMENTS:', 'Goldbrenner', 'MAKLBORO', 'Ave', 'PROMOTIONS', 'CIGARETTES', 'Sales', 'Orcutt', 'OTHER', 'ATTACHED', 'COMPETITIVE', 'WIDESPREAD?', 'INFORMATION:', 'PROMOTION:', 'Smith', 'SOURCE', 'MORRIS', 'Mr.', 'ACCOUNT', 'MANUFACTURERS:', 'Ruffalo', 'Co.,', 'Harrow', 'Manager,', '93455715', 'Jones', 'BY:', 'cc:', 'Gordon', 'Kersh', 'AND', 'REPORTED', 'Cleveland,', 'SPECIAL', 'SPRING', 'ACTIVITIES', 'Ryan', 'Best', 'Ms.'}, 'matched_labels': {'DATE:', 'SEE', 'Telford', 'HOW', 'Ridgway', 'CAMBRIDGE', 'REYNOLDS', 'Giacoio', 'Dr.', 'Mau', 'DIRECT', 'Regional', 'REGARDING:', 'McCann', 'Philip', 'Morris-', 'Cigarette', 'Daghlian', 'CORRESPONDENCE', 'Achey', 'Peterson', 'PHILIP', 'Mentor,', '4/7/88', 'PROGRAM', 'Klein,', 'TYPE', 'Lawless', 'INCENTIVE', 'Toti', 'Mastandrea', 'COMMENTS:', 'Goldbrenner', 'Ave', 'PROMOTIONS', 'CIGARETTES', 'Sales', 'Orcutt', 'OTHER', 'ATTACHED', 'COMPETITIVE', 'INFORMATION:', 'PROMOTION:', 'Smith', 'SOURCE', 'MORRIS', 'Mr.', 'ACCOUNT', 'MANUFACTURERS:', 'Ruffalo', 'Co.,', 'Harrow', 'Manager,', 'Jones', 'BY:', 'cc:', 'Gordon', 'Kersh', 'AND', 'REPORTED', 'Cleveland,', 'SPECIAL', 'SPRING', 'ACTIVITIES', 'Ryan', 'Best', 'Ms.'}, 'unmatched_labels': {'WIDESPREAD?', '93455715', 'MAKLBORO'}, 'recall': 0.9571428571428572, 'true_positives': 67, 'false_negatives': 3}
# Model: claude-3-haiku-20240307
# {'llm_output': 'RESPONSE: COMPETITIVE ACTIVITIES AND PROMOTIONS\n\nREPORTED BY: R. E. Klein, Regional Sales Manager, Cleveland, OH\n\nDATE: 4/7/88\n\nSOURCE OF INFORMATION: Best Cigarette Co., Mentor, OH\n\nMANUFACTURERS: R. J. REYNOLDS AND PHILIP MORRIS\n\nTYPE OF PROMOTION: SEE ATTACHED CORRESPONDENCE REGARDING:\n• R. J. REYNOLDS SPRING DIRECT ACCOUNT INCENTIVE PROGRAM\n• Philip Morris - SPECIAL PROMOTIONS ON MARLBORO AND CAMBRIDGE CIGARETTES\n\nHOW WIDESPREAD?\n\nOTHER COMMENTS:\n\ncc: Mr. J. R. Ave\nMr. R. M. Orcutt\nMr. M. A. Peterson\nMr. T. H. Mau\nMs. S. Ridgway\nMr. J. P. Mastrandrea\nMr. L. Gordon\nMr. G. R. Telford\nDr. S. T. Jones\nMr. C. Tosi\nMr. N. P. Ruffalo\n\nMr. T. L. Achey\nMr. P. J. McCann\nMr. A. J. Giacolo\nMr. L. H. Kersh\nMr. R. G. Ryan\nMr. P. A. Lawless\nMr. J. E. Daghlan\nMr. R. S. Goldbrener\nMs. E. R. Harrow\nMs. S. F. Smith', 'filtered_labels': {'DATE:', 'SEE', 'HOW', 'Telford', 'Ridgway', 'CAMBRIDGE', 'REYNOLDS', 'Giacoio', 'Dr.', 'Mau', 'Regional', 'DIRECT', 'REGARDING:', 'Philip', 'Morris-', 'Cigarette', 'McCann', 'Daghlian', 'CORRESPONDENCE', 'Achey', 'Peterson', 'PHILIP', 'Mentor,', '4/7/88', 'PROGRAM', 'Klein,', 'TYPE', 'Lawless', 'INCENTIVE', 'Toti', 'Mastandrea', 'COMMENTS:', 'Goldbrenner', 'MAKLBORO', 'Ave', 'PROMOTIONS', 'CIGARETTES', 'Sales', 'Orcutt', 'OTHER', 'ATTACHED', 'COMPETITIVE', 'WIDESPREAD?', 'INFORMATION:', 'PROMOTION:', 'Smith', 'SOURCE', 'MORRIS', 'Mr.', 'ACCOUNT', 'MANUFACTURERS:', 'Ruffalo', 'Co.,', 'Harrow', 'Manager,', '93455715', 'Jones', 'BY:', 'cc:', 'Gordon', 'Kersh', 'AND', 'REPORTED', 'Cleveland,', 'SPECIAL', 'SPRING', 'ACTIVITIES', 'Ryan', 'Best', 'Ms.'}, 'matched_labels': {'DATE:', 'SEE', 'Telford', 'HOW', 'Ridgway', 'CAMBRIDGE', 'REYNOLDS', 'Dr.', 'Mau', 'DIRECT', 'Regional', 'REGARDING:', 'McCann', 'Philip', 'Morris-', 'Cigarette', 'Peterson', 'CORRESPONDENCE', 'Achey', 'PHILIP', 'Mentor,', '4/7/88', 'PROGRAM', 'Klein,', 'TYPE', 'Lawless', 'INCENTIVE', 'COMMENTS:', 'Ave', 'PROMOTIONS', 'CIGARETTES', 'Sales', 'Orcutt', 'OTHER', 'ATTACHED', 'COMPETITIVE', 'WIDESPREAD?', 'INFORMATION:', 'PROMOTION:', 'Smith', 'SOURCE', 'MORRIS', 'Mr.', 'ACCOUNT', 'MANUFACTURERS:', 'Ruffalo', 'Co.,', 'Harrow', 'Manager,', 'Jones', 'BY:', 'cc:', 'Gordon', 'Kersh', 'AND', 'REPORTED', 'Cleveland,', 'SPECIAL', 'SPRING', 'ACTIVITIES', 'Ryan', 'Best', 'Ms.'}, 'unmatched_labels': {'93455715', 'Mastandrea', 'Giacoio', 'Toti', 'Goldbrenner', 'MAKLBORO', 'Daghlian'}, 'recall': 0.9, 'true_positives': 63, 'false_negatives': 7}
# Model: gpt-4o
# {'llm_output': 'RESPONSE: COMPETITIVE ACTIVITIES AND PROMOTIONS\n\nREPORTED BY:  R. E. Klein, Regional Sales Manager, Cleveland, OH\n\nDATE:  4/7/88\n\nSOURCE OF INFORMATION:  Best Cigarette Co., Mentor, OH\n\nMANUFACTURERS:  R. J. REYNOLDS AND PHILIP MORRIS\n\nTYPE OF PROMOTION: SEE ATTACHED CORRESPONDENCE REGARDING:\n     • R. J. REYNOLDS SPRING DIRECT ACCOUNT INCENTIVE PROGRAM\n     • Philip Morris - SPECIAL PROMOTIONS ON MARLBORO AND\n\nCAMBRIDGE CIGARETTES\n\nHOW WIDESPREAD?\n\nOTHER COMMENTS:\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\ncc:     Mr. J. R. Ave                   Mr. T. L. Achey\n        Mr. R. H. Orcutt               Mr. P. J. McCann\n        Mr. M. A. Peterson             Mr. A. J. Giacoio\n        Mr. T. H. Mau                  Mr. L. H. Kersh\n        Ms. S. Ridgway                 Mr. R. G. Ryan\n        Mr. J. P. Mastandrea           Mr. P. A. Lawless\n        Mr. L. Gordon                  Mr. J. E. Daghlian\n        Mr. G. R. Telford              Mr. R. S. Goldbrenner\n        Dr. S. T. Jones                Ms. E. R. Harrow\n        Mr. C. Toti                    Ms. S. F. Smith\n        Mr. N. P. Ruffalo\n\n93455715', 'filtered_labels': {'DATE:', 'SEE', 'HOW', 'Telford', 'Ridgway', 'CAMBRIDGE', 'REYNOLDS', 'Giacoio', 'Dr.', 'Mau', 'Regional', 'DIRECT', 'REGARDING:', 'Philip', 'Morris-', 'Cigarette', 'McCann', 'Daghlian', 'CORRESPONDENCE', 'Achey', 'Peterson', 'PHILIP', 'Mentor,', '4/7/88', 'PROGRAM', 'Klein,', 'TYPE', 'Lawless', 'INCENTIVE', 'Toti', 'Mastandrea', 'COMMENTS:', 'Goldbrenner', 'MAKLBORO', 'Ave', 'PROMOTIONS', 'CIGARETTES', 'Sales', 'Orcutt', 'OTHER', 'ATTACHED', 'COMPETITIVE', 'WIDESPREAD?', 'INFORMATION:', 'PROMOTION:', 'Smith', 'SOURCE', 'MORRIS', 'Mr.', 'ACCOUNT', 'MANUFACTURERS:', 'Ruffalo', 'Co.,', 'Harrow', 'Manager,', '93455715', 'Jones', 'BY:', 'cc:', 'Gordon', 'Kersh', 'AND', 'REPORTED', 'Cleveland,', 'SPECIAL', 'SPRING', 'ACTIVITIES', 'Ryan', 'Best', 'Ms.'}, 'matched_labels': {'DATE:', 'SEE', 'Telford', 'HOW', 'Ridgway', 'CAMBRIDGE', 'REYNOLDS', 'Giacoio', 'Dr.', 'Mau', 'DIRECT', 'Regional', 'REGARDING:', 'McCann', 'Philip', 'Morris-', 'Cigarette', 'Daghlian', 'CORRESPONDENCE', 'Achey', 'Peterson', 'PHILIP', 'Mentor,', '4/7/88', 'PROGRAM', 'Klein,', 'TYPE', 'Lawless', 'INCENTIVE', 'Toti', 'Mastandrea', 'COMMENTS:', 'Goldbrenner', 'Ave', 'PROMOTIONS', 'CIGARETTES', 'Sales', 'Orcutt', 'OTHER', 'ATTACHED', 'COMPETITIVE', 'WIDESPREAD?', 'INFORMATION:', 'PROMOTION:', 'Smith', 'SOURCE', 'MORRIS', 'Mr.', 'ACCOUNT', 'MANUFACTURERS:', 'Ruffalo', 'Co.,', 'Harrow', 'Manager,', '93455715', 'Jones', 'BY:', 'cc:', 'Gordon', 'Kersh', 'AND', 'REPORTED', 'Cleveland,', 'SPECIAL', 'SPRING', 'ACTIVITIES', 'Ryan', 'Best', 'Ms.'}, 'unmatched_labels': {'MAKLBORO'}, 'recall': 0.9857142857142858, 'true_positives': 69, 'false_negatives': 1}
# Model: claude-3-5-sonnet-20240620
# {'llm_output': 'RESPONSE: COMPETITIVE ACTIVITIES AND PROMOTIONS\n\nREPORTED BY: R. E. Klein, Regional Sales Manager, Cleveland, OH\n\nDATE: 4/7/88\n\nSOURCE OF INFORMATION: Best Cigarette Co., Mentor, OH\n\nMANUFACTURERS: R. J. REYNOLDS AND PHILIP MORRIS\n\nTYPE OF PROMOTION: SEE ATTACHED CORRESPONDENCE REGARDING:\n• R. J. REYNOLDS SPRING DIRECT ACCOUNT INCENTIVE PROGRAM\n• Philip Morris - SPECIAL PROMOTIONS ON MARLBORO AND\n                 CAMBRIDGE CIGARETTES\n\nHOW WIDESPREAD?\n\nOTHER COMMENTS:\n\ncc: Mr. J. R. Ave          Mr. T. L. Achey\n    Mr. R. H. Orcutt       Mr. P. J. McCann\n    Mr. M. A. Peterson     Mr. A. J. Giaccio\n    Mr. T. H. Mau          Mr. L. H. Kersh\n    Ms. S. Ridgway         Mr. R. G. Ryan\n    Mr. J. P. Mastandrea   Mr. P. A. Lawless\n    Mr. L. Gordon          Mr. J. E. Daghilan\n    Mr. G. R. Telford      Mr. R. S. Goldbrenner\n    Dr. S. T. Jones        Ms. E. R. Marrow\n    Mr. C. Toti            Ms. S. F. Smith\n    Mr. N. P. Ruffalo\n\n93-05715', 'filtered_labels': {'DATE:', 'SEE', 'HOW', 'Telford', 'Ridgway', 'CAMBRIDGE', 'REYNOLDS', 'Giacoio', 'Dr.', 'Mau', 'Regional', 'DIRECT', 'REGARDING:', 'Philip', 'Morris-', 'Cigarette', 'McCann', 'Daghlian', 'CORRESPONDENCE', 'Achey', 'Peterson', 'PHILIP', 'Mentor,', '4/7/88', 'PROGRAM', 'Klein,', 'TYPE', 'Lawless', 'INCENTIVE', 'Toti', 'Mastandrea', 'COMMENTS:', 'Goldbrenner', 'MAKLBORO', 'Ave', 'PROMOTIONS', 'CIGARETTES', 'Sales', 'Orcutt', 'OTHER', 'ATTACHED', 'COMPETITIVE', 'WIDESPREAD?', 'INFORMATION:', 'PROMOTION:', 'Smith', 'SOURCE', 'MORRIS', 'Mr.', 'ACCOUNT', 'MANUFACTURERS:', 'Ruffalo', 'Co.,', 'Harrow', 'Manager,', '93455715', 'Jones', 'BY:', 'cc:', 'Gordon', 'Kersh', 'AND', 'REPORTED', 'Cleveland,', 'SPECIAL', 'SPRING', 'ACTIVITIES', 'Ryan', 'Best', 'Ms.'}, 'matched_labels': {'DATE:', 'SEE', 'Telford', 'HOW', 'Ridgway', 'CAMBRIDGE', 'REYNOLDS', 'Dr.', 'Mau', 'DIRECT', 'Regional', 'REGARDING:', 'McCann', 'Philip', 'Morris-', 'Cigarette', 'Peterson', 'CORRESPONDENCE', 'Achey', 'PHILIP', 'Mentor,', '4/7/88', 'PROGRAM', 'Klein,', 'TYPE', 'Lawless', 'INCENTIVE', 'Toti', 'Mastandrea', 'COMMENTS:', 'Goldbrenner', 'Ave', 'PROMOTIONS', 'CIGARETTES', 'Sales', 'Orcutt', 'OTHER', 'ATTACHED', 'COMPETITIVE', 'WIDESPREAD?', 'INFORMATION:', 'PROMOTION:', 'Smith', 'SOURCE', 'MORRIS', 'Mr.', 'ACCOUNT', 'MANUFACTURERS:', 'Ruffalo', 'Co.,', 'Manager,', 'Jones', 'BY:', 'cc:', 'Gordon', 'Kersh', 'AND', 'REPORTED', 'Cleveland,', 'SPECIAL', 'SPRING', 'ACTIVITIES', 'Ryan', 'Best', 'Ms.'}, 'unmatched_labels': {'93455715', 'Giacoio', 'MAKLBORO', 'Harrow', 'Daghlian'}, 'recall': 0.9285714285714286, 'true_positives': 65, 'false_negatives': 5}

# %%
len(results['azure-document-intelligence-prebuilt'])
# Out:
# 199

# %%
def set_to_list(obj):
    if isinstance(obj, set):
        return list(obj)
    return obj

# %%
# Export document-oriented VQA results to json file
import json
with open('funsd_benchmark_results.json', 'w') as f:
    json.dump(results, f, default=set_to_list, indent=4)

# %% [markdown]
# ## Plot

# %%
import json
import matplotlib.pyplot as plt
import numpy as np

# Load the JSON data
with open('funsd_benchmark_results.json', 'r') as f:
    data = json.load(f)

# Extract recall values for each model
model_recalls = {}
for model, result in data.items():
    print(model)
    recalls = [example['recall'] for example in result]
    model_recalls[model] = np.mean(recalls)

# Prepare data for plotting
models = list(model_recalls.keys())
recalls = list(model_recalls.values())

# Create the bar plot
plt.figure(figsize=(10, 6))
plt.bar(models, recalls)
plt.title('Average Recall by Model')
plt.xlabel('Model')
plt.ylabel('Average Recall')
plt.ylim(0, 1)  # Set y-axis limit from 0 to 1 for recall values
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability

# Add value labels on top of each bar
for i, v in enumerate(recalls):
    plt.text(i, v, f'{v:.3f}', ha='center', va='bottom')

plt.tight_layout()
plt.show()
